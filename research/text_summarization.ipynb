# %%
# !pip install --upgrade accelerate
# !pip uninstall -y transformers accelerate
# !pip install transformers accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (26.2)
# Requirement already satisfied: psutil in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: pyyaml in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=1.10.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (2.2.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (1.5.0)
# Requirement already satisfied: requests in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: sympy in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
# Installing collected packages: accelerate
# Successfully installed accelerate-1.0.1
# Found existing installation: transformers 4.46.3
# Uninstalling transformers-4.46.3:
#   Successfully uninstalled transformers-4.46.3
# Found existing installation: accelerate 1.0.1
# Uninstalling accelerate-1.0.1:
#   Successfully uninstalled accelerate-1.0.1
# Collecting transformers
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Collecting accelerate
#   Using cached accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: psutil in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: torch>=1.10.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from accelerate) (2.2.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (1.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.13.2)
# Requirement already satisfied: sympy in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests->transformers) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests->transformers) (3.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests->transformers) (2026.4.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Using cached transformers-4.46.3-py3-none-any.whl (10.0 MB)
# Using cached accelerate-1.0.1-py3-none-any.whl (330 kB)
# Installing collected packages: accelerate, transformers
# Successfully installed accelerate-1.0.1 transformers-4.46.3

# %%
# %pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (3.1.0)
# Requirement already satisfied: numpy>=1.17 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (1.24.4)
# Requirement already satisfied: dill in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (3.7.0)
# Requirement already satisfied: multiprocess in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (0.36.2)
# Requirement already satisfied: packaging in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from evaluate) (26.2)
# Requirement already satisfied: filelock in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (3.10.11)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate) (1.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.13.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (3.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (2026.4.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from pandas->evaluate) (2026.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from pandas->evaluate) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (5.0.1)
# Requirement already satisfied: six>=1.5 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/gtanuj7987/Documents/Data Science Naik/Content Summarize/project-content-summarizer/venv/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline, set_seed
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from pathlib import Path
import pandas as pd
import torch
import numpy as np
import matplotlib.pyplot as plt
import evaluate
import os
import tqdm
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/gtanuj7987/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'
